# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
exp = np.genfromtxt("exp-H2O-TAMOF-1-298.dat")
sim_co2 = np.genfromtxt("sim-CO2-TAMOF-1-298K.load")
sim_n2 = np.genfromtxt("sim-N2-TAMOF-1-298K.load")

# %%
exp
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.26230000e+01, 8.93640297e-01, 2.00300000e+01, 5.10349287e+00],
#        [3.07930000e+01, 1.83796334e+00, 4.11960000e+01, 1.04964300e+01],
#        [8.09560000e+01, 2.74074973e+00, 6.14310000e+01, 1.56521553e+01],
#        [1.01500000e+02, 3.65745603e+00, 8.19780000e+01, 2.08873759e+01],
#        [1.05100000e+02, 4.55341631e+00, 1.02060000e+02, 2.60041180e+01],
#        [1.12500000e+02, 5.48765634e+00, 1.23000000e+02, 3.13394720e+01],
#        [1.22700000e+02, 6.41431181e+00, 1.43770000e+02, 3.66315113e+01],
#        [1.26800000e+02, 7.31509052e+00, 1.63960000e+02, 4.17757709e+01],
#        [1.36800000e+02, 8.25066900e+00, 1.84930000e+02, 4.71187687e+01],
#        [1.45600000e+02, 9.17598602e+00, 2.05670000e+02, 5.24031642e+01],
#        [1.61600000e+02, 1.00691802e+01, 2.25690000e+02, 5.75041092e+01],
#        [2.00300000e+02, 1.09824511e+01, 2.46160000e+02, 6.27197107e+01],
# ...

# %%
fig, ax = plt.subplots()
ax.plot(exp[:, 0], exp[:, 1])
ax.plot(sim_co2[:, 0], sim_co2[:, 1])
ax.plot(sim_n2[:, 0], sim_n2[:, 1])
ax.set_xscale("log")
